# %%
from google import genai

client = genai.Client()
response = client.models.generate_content_stream(
    model="gemini-2.5-flash",
    contents=["AI是如何工作的(請使用繁體中文回答)?"],
)
for chunk in response:
    print(chunk.text)
# Out:
# 人工智慧 (Artificial Intelligence, AI) 的運作方式，核心概念在於**模仿人類學習、思考和解決問題的能力**。雖然底層技術非常複雜，但我們可以將其簡化為幾個關鍵步驟和核心概念。
#
#
# 以下是 AI 如何工作的簡化解釋：
#
# ### 1. 核心機制：機器學習 (Machine Learning)
#
# 現代 AI 的絕大部分成功，都歸功於一種稱為「機器學習」的方法。簡單來說，機器學習就是讓
# 電腦**從數據中學習，而不是透過明確的編程指令**。想像一下教一個小孩認識貓：你不會寫一個程序來描述貓的每一個特徵（四條腿、毛茸茸、喵喵叫），
# 而是會給他看很多貓的圖片，並告訴他「這是貓」。久而久之，小孩就會自己學會辨識貓。AI 也是類似的過程。
#
# #### A. 資料收集 (Data Collection)：
# AI 的「食物」
#
# *   AI 需要大量的「資料」來學習。這些資料可以是圖片、文字、聲音、數字、行為紀錄等等。
# *   **例子：** 如果要 AI 辨識貓，就需要
# 給它成千上萬張標記為「貓」和「不是貓」的圖片。
#
# #### B. 訓練過程 (Training Process)：AI 的「學習」
#
# *   **演算法 (Algorithms)：** AI 使用各種
# 「演算法」作為學習的「食譜」或「方法論」。這些演算法會分析資料中的模式、規律和關聯性。
# *   **模型 (Model)：** 演算法學習的成果會
# 儲存在一個稱為「模型」的結構中。這個模型可以被視為 AI 學習到的「知識」或「規則集」。
# *   **神經網路 (Neural Networks) 與深度學習 (Deep Learning)：**
#
#     *   這是目前最成功且廣泛使用的機器學習方法。它受到人類大腦結構的啟發，由許多層次的「節點」(neurons) 組成，這些節點相互連接，並賦予不同的
# 「權重」(weights)。
#     *   AI 在訓練過程中會不斷調整這些節點之間的權重，就像調整旋鈕一樣，直到它能夠準確地辨識或預測。
#     *   「深度學習」
# 是神經網路的一個子集，特指使用多層（通常是數十層甚至數百層）神經網路的技術，讓 AI 能學習更抽象、複雜的模式。
# *   **迭代與優化：
# ** AI 會反覆地處理資料，比較自己的預測與正確答案之間的差異（錯誤），然後調整模型的內部參數（例如神經網路的權重），以減少錯誤，提高準確性。這個過程會重複
# 數百萬次。
#
# #### C. 預測與推論 (Prediction & Inference)：AI 的「應用」
#
# *   一旦模型被充分訓練，它就可以用來處理全新的、未見過的資料。
# *   **例子
# ：** 當你給這個訓練好的 AI 一張從未見過的新圖片時，它就能根據之前學到的知識，判斷這張圖片裡是不是有貓。這就是「預測」或「推論」。
#
#
# ### 2. 關鍵概念的再深入
#
# *   **資料 (Data)：** AI 的燃料。資料的數量、品質和相關性，直接決定了 AI 的能力上限。
# *   **演算法 (Algorithms)：** AI
#  如何學習的指令集或數學公式。例如，決策樹、支持向量機、集群演算法，以及最常見的神經網路演算法。
# *   **模型 (Model)：** 經過訓練的 AI 本身。
# 它包含了從資料中學習到的模式和知識。
# *   **算力 (Computational Power)：** 訓練 AI 模型需要巨大的計算能力，特別是對於深度學習模型。這通常依賴於高性能的圖形處理器 (
# GPU) 或專用的 AI 晶片。
#
# ### 3. 簡化比喻
#
# 想像 AI 是一個非常勤奮的學生：
#
# 1.  **收集資料**：你給他一大堆標記好的
# 數學題目（練習題和答案）。
# 2.  **學習演算法**：你教他各種數學公式和解題方法。
# 3.  **訓練模型**：學生不斷地練習這些題目，嘗試各種方法，並
# 根據答案修正自己的解題步驟（調整模型參數）。
# 4.  **預測與推論**：當他學會了足夠的知識，你就可以給他一個全新的、沒見過的題目，他就能根據
# 學到的知識給出答案。
#
# ### 4. AI 的進化與改善
#
# AI 模型的表現可以透過以下方式不斷改善：
# *   提供更多、更高品質的訓練資料。
# *   開發更先進、更有效
# 率的演算法。
# *   增加計算能力，以訓練更大、更複雜的模型。
# *   從實際應用中獲得回饋，並重新訓練模型。
#
# ### 常見的 AI 應用領域
#
# 基於上述工作
# 原理，AI 廣泛應用於：
#
# *   **語音辨識：** Siri、Google Assistant 等語音助理。
# *   **影像辨識：** 人臉辨識、自動駕駛汽車的環境感知
# 。
# *   **自然語言處理 (NLP)：** 翻譯軟體、聊天機器人、文字生成（如 ChatGPT）。
# *   **推薦系統：** Netflix 的電影推薦、Amazon 的商品推薦。
# *   **
# 決策支援：** 股票交易預測、醫療診斷輔助。
#
# 總結來說，AI 的核心工作方式就是**透過機器學習技術，從大量的數據中自動學習和提取有用的模式，然後利用
# 這些模式來執行特定的任務、做出預測或生成內容。** 它並非真正擁有意識或情感，而是強大的模式識別和問題解決工具。

# %%
import PIL.Image
from google import genai
from IPython.display import display, Markdown

client = genai.Client()
image = PIL.Image.open('09491_1400x.webp')
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[image, "請告訴我這是什麼,還有關於它的一些資訊"]
)

display(Markdown(response.text))
# Out:
# 這是一個**查理布朗 (Charlie Brown) 的瓷偶**。
#
# 以下是關於它的一些資訊：
#
# 1.  **角色：** 它是來自查爾斯·舒爾茨 (Charles M. Schulz) 創作的經典漫畫《花生漫畫》(Peanuts) 中的主角——**查理布朗**。他以其標誌性的黃色帶黑色鋸齒條紋的T恤、圓圓的頭和常常有點倒霉的個性而聞名。
#
# 2.  **製造商：** 這款精美的瓷偶是由西班牙著名的瓷器製造商 **Lladro (雅致)** 製作的。Lladro 以其高品質、手工製作且造型精緻的瓷器藝術品聞名於世，他們經常與知名IP（如迪士尼、花生漫畫等）合作推出聯名系列。
#
# 3.  **設計細節：**
#     *   瓷偶捕捉了查理布朗經典的形象，他穿著那件獨特的黃色T恤。
#     *   他雙手捧著一束白色的小花，臉上帶著溫和、略帶羞澀的笑容。這個姿態通常傳達著純真、愛意、友誼，或是一種表達感謝和歉意的溫柔姿態，非常符合查理布朗善良而略顯笨拙的性格。
#     *   瓷偶表面呈現出Lladro標誌性的光面瓷質地，光滑且有光澤，展現了極高的工藝水平。底座通常也會有精細的紋理設計。
#
# 4.  **收藏價值：** 作為Lladro出品的系列作品，這類瓷偶具有很高的收藏價值。它們不僅是《花生漫畫》粉絲的收藏品，也是藝術瓷器收藏家們青睞的對象，代表著精湛的工藝和經典的文化符號。
#
# 總而言之，這是一款由Lladro製作的精美查理布朗瓷偶，展現了他純真善良的形象，是《花生漫畫》粉絲和瓷器愛好者不可多得的收藏品。
